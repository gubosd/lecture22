# %% [markdown]
# ## 머신러닝
# # 신경망

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 신경망 수작업 계산

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
X = iris.data[:, :3] # 속성 3개
y = iris.data[:, 3] # petal_width
X.shape, y.shape
# Out:
# ((150, 3), (150,))

# %%
# 가중치 초기화
W1 = np.random.randn(3, 100)
b1 = np.random.randn(100)
W2 = np.random.randn(100, 10)
b2 = np.random.randn(10)
W3 = np.random.randn(10,1)
b3 = np.random.randn(1)
W1.shape, b1.shape, W2.shape, b2.shape, W3.shape, b3.shape
# Out:
# ((3, 100), (100,), (100, 10), (10,), (10, 1), (1,))

# %%
y1 = X@W1 + b1
y1[y1<0] = 0 # 활성화함수(relu) 적용
y1.shape
# Out:
# (150, 100)

# %%
y2 = y1@W2 + b2
y2[y2<0] = 0
y2.shape
# Out:
# (150, 10)

# %%
y3 = y2@W3 + b3 # 출력층에는 활성화함수 적용하지 않음 (선형회귀의 경우)
y3.shape
# Out:
# (150, 1)

# %%
y_pred = y3.ravel()
y_pred.shape
# Out:
# (150,)

# %%
mse = ((y-y_pred)**2).mean()
mse
# Out:
# 490.95964657911907

# %%
y_pred
# Out:
# array([ 9.38463985, 10.09321266,  8.17764146, 13.68759393, 10.18785946,
#        15.69787709, 10.44850228, 12.00880961, 11.52941268, 12.95422264,
#        10.2763499 , 15.4823753 , 10.33766976,  7.61559688, 12.68542153,
#        12.69790208, 11.33976524,  9.38463985, 15.32171387, 11.65882173,
#        17.16850447, 11.20989092, 12.88677097, 18.13291864, 23.72549171,
#        15.99860459, 15.03551617, 11.267825  ,  8.55039036, 16.29405581,
#        16.27360425, 11.09019355, 12.11241287, 12.43951884, 12.95422264,
#         8.07063573,  9.14882786, 10.4990398 ,  8.24057363, 11.78538004,
#         9.07764095,  9.86533728,  9.17420252, 14.74139069, 21.79948029,
#        10.33766976, 13.6355847 , 10.39875488, 10.58753024,  9.20701196,
#        36.31008017, 34.89180391, 33.59207335, 22.396398  , 29.94703708,
#        24.90180692, 34.50079137, 25.63916106, 31.50827325, 25.86738656,
#        20.12942433, 31.64490578, 25.52991501, 27.09906062, 33.74301882,
#        35.87902827, 27.38382563, 27.57561007, 23.35619341, 25.99617013,
#        29.55556891, 31.92653651, 23.09044154, 25.5925685 , 32.35758841,
#        33.97540842, 29.99048176, 30.13611905, 28.36326966, 31.32645595,
#        25.29284836, 26.13876946, 29.69354805, 20.39403656, 26.11499512,
#        35.80390774, 33.58868753, 25.48253745, 30.86664101, 23.70488621,
#        21.4658546 , 29.60658975, 27.57874835, 25.02420456, 25.55711113,
#        30.68346818, 29.26597867, 31.07748648, 30.91918065, 28.51238078,
#        21.56006847, 18.92312235, 26.51254894, 21.5277396 , 22.69694413,
#        26.75428934, 13.06319493, 25.53604469, 21.38703594, 32.39377839,
#        30.51412398, 22.78122563, 26.5481027 , 17.76148829, 20.34235312,
#        28.06496541, 24.31822867, 33.5918394 , 23.01166664, 18.14279566,
#        27.87325988, 20.63763057, 25.34458283, 24.60538551, 28.18082316,
#        28.03855736, 25.57602243, 26.7586533 , 22.09866535, 27.49019778,
#        26.27071   , 36.77302752, 22.09866535, 23.77616517, 18.74222616,
#        29.30550665, 28.32329221, 25.05007118, 27.0735502 , 29.3036458 ,
#        26.09574427, 31.97861259, 18.92312235, 25.79200756, 28.18082316,
#        28.35280786, 22.48756664, 26.60258879, 29.48629524, 23.94468777])

# %% [markdown]
# ### 이후 작업
# > - 오차(mse)를 줄이도록 가중치들(W1,b1,W2,b2,W3,b3)의 값을 바꾼다.
# > - 이는 오차역전파법(backpropagation)을 이용해 수행한다.
# > - tensorflow 가 하는 역할은 오차역전파법을 지원하는 것이다.

# %% [markdown]
# ### tensorflow 와 keras 적용

# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
tf.__version__
# Out:
# '2.5.0'

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
X = iris.data[:, :3] # 속성 3개
y = iris.data[:, 3] # petal_width
X.shape, y.shape
# Out:
# ((150, 3), (150,))

# %%
model = keras.models.Sequential()
model.add(keras.layers.Dense(100, activation='relu', input_shape=(3,)))
model.add(keras.layers.Dense(10, activation='relu'))
model.add(keras.layers.Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 100)               400
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                1010
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 1,421
# Trainable params: 1,421
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred = model.predict(X)
y_pred.shape
# Out:
# (150, 1)

# %% [markdown]
# ### 신경망 훈련

# %%
model.compile(loss='mse', optimizer='adam')

# %%
history = model.fit(X, y, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1793
# Epoch 2/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6524
# Epoch 3/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3703
# Epoch 4/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3059
# Epoch 5/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3040
# Epoch 6/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2546
# Epoch 7/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1998
# Epoch 8/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1736
# Epoch 9/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1580
# Epoch 10/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1357
# Epoch 11/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1142
# Epoch 12/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1026
# Epoch 13/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0894
# Epoch 14/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0763
# Epoch 15/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0689
# Epoch 16/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0615
# Epoch 17/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0550
# Epoch 18/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 19/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0484
# Epoch 20/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0460
# Epoch 21/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0448
# Epoch 22/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0437
# Epoch 23/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0429
# Epoch 24/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0423
# Epoch 25/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0423
# Epoch 26/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0418
# Epoch 27/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0416
# Epoch 28/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0415
# Epoch 29/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0416
# Epoch 30/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0410
# Epoch 31/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0412
# Epoch 32/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0415
# Epoch 33/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0413
# Epoch 34/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0413
# Epoch 35/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0416
# Epoch 36/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0409
# Epoch 37/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0408
# Epoch 38/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0407
# Epoch 39/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0405
# Epoch 40/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0403
# Epoch 41/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0407
# Epoch 42/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0401
# Epoch 43/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0399
# Epoch 44/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0398
# Epoch 45/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0397
# Epoch 46/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0396
# Epoch 47/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0396
# Epoch 48/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0394
# Epoch 49/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0391
# Epoch 50/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0391

# %%
y_pred = model.predict(X)

# %%
plt.plot(y)
plt.plot(y_pred)
plt.legend(['y', 'y_pred'])

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# ### MNIST 분류

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
28*28
# Out:
# 784

# %%
X_train.max(), X_train.min()
# Out:
# (255, 0)

# %%
plt.imshow(X_train[0], cmap='gray')
plt.colorbar()

# %%
### 데이터 전처리
X_train = X_train.reshape(-1, 28*28)/255
X_test = X_test.reshape(-1, 28*28)/255
X_train.shape, X_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %%
### 원핫인코딩
y_train = np.eye(10)[y_train]
y_test  = np.eye(10)[y_test]
y_train.shape, y_test.shape
# Out:
# ((60000, 10), (10000, 10))

# %%
model = keras.models.Sequential()
model.add(keras.layers.Dense(100, activation='relu', input_shape=(784,)))
model.add(keras.layers.Dense(50, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax')) # 10개 클래스로 분류 => softmax

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 100)               78500
# _________________________________________________________________
# dense_19 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                510
# =================================================================
# Total params: 84,060
# Trainable params: 84,060
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

# %%
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.25)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.2954 - acc: 0.9160 - val_loss: 0.1618 - val_acc: 0.9520
# Epoch 2/20
# 1407/1407 [==============================] - 12s 8ms/step - loss: 0.1290 - acc: 0.9614 - val_loss: 0.1228 - val_acc: 0.9629
# Epoch 3/20
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.0907 - acc: 0.9724 - val_loss: 0.1206 - val_acc: 0.9637
# Epoch 4/20
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.0673 - acc: 0.9788 - val_loss: 0.1080 - val_acc: 0.9684
# Epoch 5/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.0518 - acc: 0.9836 - val_loss: 0.1161 - val_acc: 0.9671
# Epoch 6/20
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0432 - acc: 0.9860 - val_loss: 0.1116 - val_acc: 0.9698
# Epoch 7/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0347 - acc: 0.9890 - val_loss: 0.1205 - val_acc: 0.9695
# Epoch 8/20
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.0273 - acc: 0.9911 - val_loss: 0.1515 - val_acc: 0.9616
# Epoch 9/20
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.0246 - acc: 0.9918 - val_loss: 0.1321 - val_acc: 0.9689
# Epoch 10/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 0.0196 - acc: 0.9934 - val_loss: 0.1320 - val_acc: 0.9688
# Epoch 11/20
# 1407/1407 [==============================] - 16s 12ms/step - loss: 0.0200 - acc: 0.9933 - val_loss: 0.1236 - val_acc: 0.9722
# Epoch 12/20
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.0165 - acc: 0.9945 - val_loss: 0.1284 - val_acc: 0.9745
# Epoch 13/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 0.0151 - acc: 0.9947 - val_loss: 0.1499 - val_acc: 0.9699
# Epoch 14/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0137 - acc: 0.9957 - val_loss: 0.1759 - val_acc: 0.9667
# Epoch 15/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0117 - acc: 0.9959 - val_loss: 0.1479 - val_acc: 0.9711
# Epoch 16/20
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.0126 - acc: 0.9961 - val_loss: 0.1396 - val_acc: 0.9732
# Epoch 17/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0133 - acc: 0.9955 - val_loss: 0.1479 - val_acc: 0.9719
# Epoch 18/20
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.0089 - acc: 0.9970 - val_loss: 0.1666 - val_acc: 0.9701
# Epoch 19/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.0112 - acc: 0.9961 - val_loss: 0.1481 - val_acc: 0.9743
# Epoch 20/20
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0112 - acc: 0.9962 - val_loss: 0.1604 - val_acc: 0.9721

# %%
plt.subplot(1,2,1)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.legend(['acc', 'val_acc'])

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])

# %%
y_pred = model.predict(X_test)
y_pred.shape
# Out:
# (10000, 10)

# %%
y_pred[:20].argmax(axis=1)
# Out:
# array([7, 2, 1, 0, 4, 1, 4, 9, 5, 9, 0, 6, 9, 0, 1, 5, 9, 7, 8, 4],
#       dtype=int64)

# %%
y_test[:20].argmax(axis=1)
# Out:
# array([7, 2, 1, 0, 4, 1, 4, 9, 5, 9, 0, 6, 9, 0, 1, 5, 9, 7, 3, 4],
#       dtype=int64)

# %%
plt.imshow(X_test[18].reshape(28,28), cmap='gray')

# %% [markdown]
# ### 딥러닝 적용
# - CNN : Convolution Neural Network

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - convolution
# ![image.png](attachment:image.png)

# %% [markdown]
# - pooling
# ![image.png](attachment:image.png)

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
### 데이터 전처리
X_train = X_train.reshape(-1,28,28,1)/255 # 0~1 사이의 값으로 정규화
X_test = X_test.reshape(-1,28,28,1)/255
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28, 1), (10000, 28, 28, 1))

# %%
### 원핫인코딩
y_train = np.eye(10)[y_train]
y_test  = np.eye(10)[y_test]
y_train.shape, y_test.shape
# Out:
# ((60000, 10), (10000, 10))

# %%
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(filters=30, kernel_size=(3,3), padding='same',
                              activation='relu', input_shape=(28,28,1)))
model.add(keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(keras.layers.Conv2D(filters=60, kernel_size=(3,3), padding='same',
                              activation='relu'))
model.add(keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(keras.layers.Conv2D(filters=120, kernel_size=(3,3), padding='same',
                              activation='relu'))
model.add(keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 28, 28, 30)        300
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 30)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 60)        16260
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 60)          0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 7, 7, 120)         64920
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 3, 3, 120)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1080)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 100)               108100
# _________________________________________________________________
# dense_28 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 190,590
# Trainable params: 190,590
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=100, validation_split=0.25)
# Out:
# Epoch 1/10
# 450/450 [==============================] - 19s 26ms/step - loss: 0.2361 - acc: 0.9295 - val_loss: 0.0793 - val_acc: 0.9766
# Epoch 2/10
# 450/450 [==============================] - 11s 24ms/step - loss: 0.0581 - acc: 0.9823 - val_loss: 0.0505 - val_acc: 0.9840
# Epoch 3/10
# 450/450 [==============================] - 10s 23ms/step - loss: 0.0406 - acc: 0.9868 - val_loss: 0.0462 - val_acc: 0.9863
# Epoch 4/10
# 450/450 [==============================] - 12s 26ms/step - loss: 0.0300 - acc: 0.9906 - val_loss: 0.0437 - val_acc: 0.9878
# Epoch 5/10
# 450/450 [==============================] - 10s 21ms/step - loss: 0.0242 - acc: 0.9923 - val_loss: 0.0406 - val_acc: 0.9885
# Epoch 6/10
# 450/450 [==============================] - 11s 24ms/step - loss: 0.0185 - acc: 0.9933 - val_loss: 0.0368 - val_acc: 0.9895
# Epoch 7/10
# 450/450 [==============================] - 11s 25ms/step - loss: 0.0166 - acc: 0.9942 - val_loss: 0.0319 - val_acc: 0.9909
# Epoch 8/10
# 450/450 [==============================] - 10s 23ms/step - loss: 0.0124 - acc: 0.9959 - val_loss: 0.0352 - val_acc: 0.9894
# Epoch 9/10
# 450/450 [==============================] - 12s 26ms/step - loss: 0.0110 - acc: 0.9960 - val_loss: 0.0358 - val_acc: 0.9905
# Epoch 10/10
# 450/450 [==============================] - 12s 26ms/step - loss: 0.0096 - acc: 0.9968 - val_loss: 0.0366 - val_acc: 0.9904

# %%
plt.subplot(1,2,1)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.legend(['acc', 'val_acc'])

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])

# %%
y_pred = model.predict(X_test)
y_pred.shape
# Out:
# (10000, 10)

# %%
np.where(y_pred.argmax(axis=1) != y_test.argmax(axis=1)) # 틀린 이미지 번호
# Out:
# (array([ 445,  582,  583,  938,  947, 1014, 1072, 1112, 1182, 1226, 1232,
#         1247, 1319, 1364, 1393, 1681, 1709, 1737, 1790, 1901, 2018, 2035,
#         2118, 2129, 2130, 2293, 2597, 2654, 2896, 2939, 2953, 2959, 3225,
#         3422, 3441, 3475, 3520, 3534, 3558, 3762, 3778, 3780, 3808, 3850,
#         4078, 4176, 4284, 4369, 4487, 4497, 4507, 4571, 4740, 4761, 4807,
#         4814, 5654, 5937, 5997, 6166, 6172, 6571, 6572, 6576, 6597, 6623,
#         6651, 7216, 8520, 9009, 9505, 9642, 9664, 9679, 9729], dtype=int64),)

# %%
plt.imshow(X_test[445,:,:,0], cmap='gray')

# %%
(y_pred.argmax(axis=1) == y_test.argmax(axis=1)).mean() # 정확도 계산
# Out:
# 0.9925
